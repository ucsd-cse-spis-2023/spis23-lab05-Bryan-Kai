# %% [markdown]
# <a href="https://colab.research.google.com/github/ucsd-cse-spis-2023/spis23-lab05-Bryan-Kai/blob/main/lab05Warmup_Kai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# instructs Python to import the image portion of the PIL image library
from PIL import Image

# open the bear image and stores a reference to it in the bear variable
bear = Image.open("bear.png")

#view the image stored in the bear variable
display(bear)

#saves the current image into a new file
bear.save("new_bear.png")

# returns the size of the bear image which happens to be (600 x 800)
bear.size


pixel = bear.getpixel((100, 200))

print(pixel)

bear.putpixel((100, 200), (0, 0, 0))

for i in range(100):
  bear.putpixel((i, 200), (0, 0, 0))

def invert(im):
  (width, height) = im.size

  for x in range(width):
    for y in range(height):
      (red, green, blue) = im.getpixel((x, y))
      im.putpixel((x, y), (255 - red, 255 - green, 255 - blue))

def invert_block(im):
  (width, height) = im.size

  for x in range(width):
    for y in range(height):
      if x > width // 2 and y < height // 2:
        (red, green, blue) = im.getpixel((x, y))
        im.putpixel((x, y), (255 - red, 255 - green, 255 - blue))


"""invert(bear)"""
invert_block(bear)
display(bear)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=600x800>
# (166, 201, 239)
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=600x800>
